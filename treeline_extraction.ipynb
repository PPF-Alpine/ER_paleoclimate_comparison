# %%
# -------------------------------------------------------------#
#           Step 0, import libraries                          #
# -------------------------------------------------------------#
import geopandas as gpd
import rasterio
from rasterio import mask
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
# -------------------------------------------------------------#
#           Step 1, import the data                           #
# -------------------------------------------------------------#
GMBA = {"path": "./data/GMBA/GMBA_Inventory_v2.0_Level_03.shp"}

DEM = {"path": "./data/DEM/GMTED2010_30.tiff"}

TREE_LINE_TEMP = {
    "path": "./data/temp_treeline/Alpine_Biome_Suzette.shp"
}  # temp_treeline values are in column: "MEAN_Avg_c", names of mountain ranges are in column "MapName"

MARGIN = 0.25  # margin for the treeline temperature

# Models (using the orininal data, not resampled)
CHELSA_MODEL = {"path": Path("./data/CHELSA/CHELSA_TraCE21k_bio01_-190_V1.0.tif")}
BEYER_MODEL = {"path": Path("./data/Beyer/LateQuaternary_Environment_-21020.tif")}
PGEM_MODEL = {"path": Path("./data/PALEO-PGEM/PALEO-PGEM-Series_bio1_mean_-21020.tif")}
WORLDCLIM_MODEL = {"path": Path("./data/Worldclim1/cclgmbi1_21ka_2.5.tif")} #these values need to be multiplied by 10 to get normal celcius values
ECOCLIMATE_MODEL = {"path": Path("./data/ecoclimate/bio#baseline_Modern(1950-1999)#CCSM_LGM(21ka)_bio1.tif")}
GGC_MODEL = {"path": Path("./data/ggc/ggc2.tif")}

#do not use
#LR_PRESENT = {"path": Path("./data/CHELSA/CHELSA_TraCE21k_bio01_20_V1.0.tif")}

# %%
# Check dimensions of the rasters CHELSA_MODEL, BEYER_MODEL, PGEM_MODEL, WORLDCLIM_MODEL, ECOCLIMATE_MODEL, GGC_MODEL
with rasterio.open(CHELSA_MODEL["path"]) as src:
    print("chelsa",src.width, src.height)
with rasterio.open(BEYER_MODEL["path"]) as src: 
    print("beyer",src.width, src.height)        
with rasterio.open(PGEM_MODEL["path"]) as src:
    print("paleo-pgem",src.width, src.height)
with rasterio.open(WORLDCLIM_MODEL["path"]) as src:
    print("worldclim",src.width, src.height)
with rasterio.open(ECOCLIMATE_MODEL["path"]) as src:
    print("ecoclimate",src.width, src.height)
with rasterio.open(GGC_MODEL["path"]) as src:
    print("ggc",src.width, src.height)

# %%
# load and test dimensions of the resampled files
BEYER_RES_MODEL = {"path": Path("./data/Beyer/resampled/beyer_lgm_resampled.tif")}
with rasterio.open(BEYER_RES_MODEL["path"]) as src: 
    print("beyer res",src.width, src.height)  

PGEM_RES_MODEL = {"path": Path("./data/PALEO-PGEM/resampled/paleopgem_lgm_resampled.tif")}
with rasterio.open(PGEM_RES_MODEL["path"]) as src:
    print("paleo-pgem res",src.width, src.height)

WORLDCLIM_RES_MODEL = {"path": Path("./data/Worldclim1/resampled/worldclim_lgm_resampled.tif")}
with rasterio.open(WORLDCLIM_RES_MODEL["path"]) as src:
    print("worldclim res",src.width, src.height)

ECOCLIMATE_RES_MODEL = {"path": Path("./data/ecoclimate/resampled/ecoclimate_lgm_resampled.tif")}
with rasterio.open(ECOCLIMATE_RES_MODEL["path"]) as src:
    print("ecoclimate res",src.width, src.height)

# %%
# -------------------------------------------------------------#
#   Step 2, create the right variables for the loop            #
# -------------------------------------------------------------#

# DEM must be added to lgm raster of pgem model
# extract the elevation value from the dem where the lgm temp of pgem equals the treeline, temp +- the margin, for each mountain range
# save the extracted elevation value in a new raster, attach the name of the mountain range
# save the raster in a new folder   ./data/elevation_treeline

# Read the shapefile
mountain_ranges = gpd.read_file(GMBA["path"])

# Read the temperature shapefile
treeline_temp = gpd.read_file(TREE_LINE_TEMP["path"])

# Read the DEM
dem = rasterio.open(DEM["path"])

# Read the model
temperature_raster = rasterio.open(LR_PRESENT["path"]) #NOTE: CHANGE THIS TO THE MODEL YOU WANT TO USE

# If the temperature raster is smaller than the dem, resample the dem to the width of the temperature raster
if temperature_raster.width != dem.width:
    # NOTE: THIS ASSUMES SAME PROJECTION FOR ALL RASTERS
    # Scale to same width as the temperature raster, and keep the aspect ratio
    dem_scale = int(dem.width / temperature_raster.width)
    new_dem_height = int(dem.height / dem_scale)
    new_dem_width = int(dem.width / dem_scale)
    dem_downsampled = np.zeros((new_dem_height, new_dem_width), dtype=dem.read(1).dtype)
    dem_downsampled, new_dem_transform = rasterio.warp.reproject(source=dem.read(),
                                destination=dem_downsampled,
                                src_transform=dem.transform,
                                dst_transform=temperature_raster.transform,
                                src_crs=dem.crs,
                                dst_crs=dem.crs,
                                dst_nodata=dem.nodata,
                                resampling=rasterio.enums.Resampling.average)
    
    # resize dem_downsampled to the size of the temperature raster
    dem_downsampled = dem_downsampled[:temperature_raster.height, :temperature_raster.width]
    
    new_dem_profile = dem.profile
    new_dem_profile.update(transform=new_dem_transform, driver='GTiff',
                            height=temperature_raster.height, width=temperature_raster.width)

    with rasterio.open("./data/dem_downsampled.tif", "w", **new_dem_profile) as dst:
        dst.write(dem_downsampled, 1)
    
    # Overwrite the dem object with the downsampled dem
    dem = rasterio.open("./data/dem_downsampled.tif")

# %% [markdown]
# ### FILE BELOW WAS SPLIT INTO TWO LOOPS BECAUSE OF MEMORY CONCERNS
# Running time Chelsa and ggc was 67 min, Worldclim 2.5 minutes, other models < 1 minute.

# %%
# -------------------------------------------------------------#
#   Step 3, masking, padding, extraction, saving               #
# -------------------------------------------------------------#

# create an empty mask the size of the dem
global_dem_mask = np.full((dem.height, dem.width), False, dtype=bool)

global_meta = dem.meta.copy()
global_meta.update(
    {
        "driver": "GTiff",
        "nodata": -999,
        "compress": "lzw",
    }
)
temperature_not_found = []

print("Calculating the elevation for the biome")
# Loop over the mountain ranges
for idx, mountain_range in tqdm(list(mountain_ranges.iterrows())):
    # Get the name of the mountain range
    mountain_range_name = mountain_range["MapName"]
    mountain_range_temperature = treeline_temp["MEAN_Avg_c"][treeline_temp["MapName"] == mountain_range_name]
    # NOTE: THIS CHECK IS HERE TO STOP THE CODE FROM BREAKING WHEN NO TEMPERATURE IS FOUND
    if mountain_range_temperature.empty:
        temperature_not_found.append(mountain_range_name)
        continue

    # Mask the CHELSA model with the mountain range geometry
    temperature_raster_within_mountain_range, temperature_raster_within_mountain_range_transform = mask.mask(
        temperature_raster, [mountain_range["geometry"]], nodata=-999, all_touched=True)



    # Set mask to True where the temperature is below the treeline temperature
    global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
                     True,
                        False))


# # Save the global dem raster for the biome NOTE:>>>CHANGE NAME<<<
with rasterio.open("./data/elevation_treeline_biome/elevation_biome_lr_present.tif", "w", **global_meta) as dst:
    dst.write(np.where(global_dem_mask, dem.read(1), -999), 1)


print("Calculating the elevation for the treeline")
# Reset the global mask
global_dem_mask = False
# Loop over the mountain ranges
for idx, mountain_range in tqdm(list(mountain_ranges.iterrows())):
    # Get the name of the mountain range
    mountain_range_name = mountain_range["MapName"]
    mountain_range_temperature = treeline_temp["MEAN_Avg_c"][treeline_temp["MapName"] == mountain_range_name]
    # NOTE: THIS CHECK IS HERE TO STOP THE CODE FROM BREAKING WHEN NO TEMPERATURE IS FOUND
    if mountain_range_temperature.empty:
        continue

    # Mask the CHELSA model with the mountain range geometry
    temperature_raster_within_mountain_range, temperature_raster_within_mountain_range_transform = mask.mask(
        temperature_raster, [mountain_range["geometry"]], nodata=-999, all_touched=True)

    # create masked array for chelsa_within_mountain_range
    masked_temperature_raster = np.ma.masked_array(temperature_raster_within_mountain_range[0], temperature_raster_within_mountain_range[0] == -999)

    # Find the mask for the treeline 
    global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
        True,
        False,
    ))
                                    
# Save the global dem raster for the treeline NOTE:>>>CHANGE NAME<<<
with rasterio.open("./data/elevation_treeline_biome/elevation_treeline_lr_present.tif", "w", **global_meta) as dst:
    dst.write(np.where(global_dem_mask, dem.read(1), -999), 1)
    
# Report on the mountain ranges where the temperature was not found
print("NO TEMPERATURES FOUND FOR FOLLOWING MOUNTAIN RANGE NAMES:", "\n".join(temperature_not_found))
# Out:
# Calculating the elevation for the biome
#   0%|          | 0/178 [00:00<?, ?it/s]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   1%|          | 1/178 [00:26<1:18:09, 26.50s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   1%|          | 2/178 [00:47<1:08:27, 23.34s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   2%|▏         | 3/178 [01:08<1:04:59, 22.28s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   2%|▏         | 4/178 [01:30<1:03:34, 21.92s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   3%|▎         | 5/178 [01:50<1:01:43, 21.40s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   3%|▎         | 6/178 [02:11<1:00:42, 21.18s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   4%|▍         | 7/178 [02:32<1:00:07, 21.09s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   4%|▍         | 8/178 [02:53<59:35, 21.03s/it]  C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   5%|▌         | 9/178 [03:14<59:12, 21.02s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   6%|▌         | 10/178 [03:35<58:57, 21.06s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   6%|▌         | 11/178 [03:55<58:19, 20.96s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   7%|▋         | 12/178 [04:17<58:31, 21.15s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#   7%|▋         | 13/178 [04:39<58:29, 21.27s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  10%|▉         | 17/178 [04:59<29:39, 11.06s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  10%|█         | 18/178 [05:21<34:40, 13.00s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  11%|█         | 19/178 [05:43<39:18, 14.84s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  11%|█         | 20/178 [06:03<42:32, 16.15s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  12%|█▏        | 21/178 [06:24<45:13, 17.28s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  12%|█▏        | 22/178 [06:45<47:25, 18.24s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  13%|█▎        | 23/178 [07:06<48:56, 18.95s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  13%|█▎        | 24/178 [07:26<49:51, 19.43s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  16%|█▋        | 29/178 [07:47<22:59,  9.26s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  17%|█▋        | 30/178 [08:08<27:17, 11.07s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  17%|█▋        | 31/178 [08:28<31:27, 12.84s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  19%|█▊        | 33/178 [08:49<28:51, 11.94s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  19%|█▉        | 34/178 [09:10<33:00, 13.75s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  20%|█▉        | 35/178 [09:31<36:26, 15.29s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  20%|██        | 36/178 [09:52<39:25, 16.66s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  21%|██▏       | 38/178 [10:12<32:56, 14.12s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  22%|██▏       | 39/178 [10:33<36:19, 15.68s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  23%|██▎       | 41/178 [10:55<31:18, 13.71s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  24%|██▎       | 42/178 [11:16<34:50, 15.37s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  25%|██▍       | 44/178 [11:37<30:09, 13.51s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  25%|██▌       | 45/178 [11:58<33:39, 15.19s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  26%|██▌       | 46/178 [12:19<36:13, 16.47s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  28%|██▊       | 49/178 [12:40<25:11, 11.72s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  29%|██▊       | 51/178 [13:01<24:03, 11.37s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  29%|██▉       | 52/178 [13:22<27:36, 13.14s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  30%|██▉       | 53/178 [13:43<30:53, 14.83s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  30%|███       | 54/178 [14:04<33:37, 16.27s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  32%|███▏      | 57/178 [14:26<23:35, 11.69s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  33%|███▎      | 58/178 [14:46<26:52, 13.44s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  34%|███▍      | 61/178 [15:09<21:06, 10.83s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  38%|███▊      | 67/178 [15:31<12:28,  6.74s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  38%|███▊      | 68/178 [15:53<15:44,  8.58s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  39%|███▉      | 69/178 [16:14<18:49, 10.36s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  39%|███▉      | 70/178 [16:36<22:16, 12.38s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  40%|███▉      | 71/178 [16:58<25:13, 14.14s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  41%|████      | 73/178 [17:19<22:29, 12.85s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  42%|████▏     | 74/178 [17:39<25:02, 14.44s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  42%|████▏     | 75/178 [18:00<27:14, 15.86s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  43%|████▎     | 76/178 [18:20<28:48, 16.95s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  43%|████▎     | 77/178 [18:41<30:15, 17.97s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  44%|████▍     | 78/178 [19:02<31:15, 18.75s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  44%|████▍     | 79/178 [19:23<32:01, 19.40s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  45%|████▍     | 80/178 [19:44<32:27, 19.87s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  47%|████▋     | 83/178 [20:05<20:13, 12.77s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  47%|████▋     | 84/178 [20:26<22:33, 14.40s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  48%|████▊     | 85/178 [20:47<24:37, 15.89s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  49%|████▉     | 87/178 [21:07<20:48, 13.73s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  49%|████▉     | 88/178 [21:28<22:56, 15.29s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  50%|█████     | 89/178 [21:49<24:38, 16.61s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  54%|█████▍    | 96/178 [22:10<09:30,  6.96s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  54%|█████▍    | 97/178 [22:30<11:44,  8.70s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  57%|█████▋    | 101/178 [22:51<09:16,  7.23s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  57%|█████▋    | 102/178 [23:12<11:20,  8.96s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  58%|█████▊    | 103/178 [23:32<13:27, 10.77s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  58%|█████▊    | 104/178 [23:53<15:30, 12.57s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  59%|█████▉    | 105/178 [24:14<17:23, 14.29s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  62%|██████▏   | 110/178 [24:35<09:21,  8.25s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  62%|██████▏   | 111/178 [24:55<11:14, 10.07s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  63%|██████▎   | 112/178 [25:16<13:04, 11.89s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  64%|██████▍   | 114/178 [25:37<12:12, 11.44s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  65%|██████▍   | 115/178 [25:58<13:53, 13.23s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  69%|██████▊   | 122/178 [26:19<06:07,  6.56s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  72%|███████▏  | 128/178 [26:40<04:18,  5.17s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  72%|███████▏  | 129/178 [27:01<05:27,  6.68s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  74%|███████▎  | 131/178 [27:21<05:51,  7.47s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  75%|███████▍  | 133/178 [27:42<06:05,  8.12s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  75%|███████▌  | 134/178 [28:02<07:14,  9.88s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  77%|███████▋  | 137/178 [28:23<05:58,  8.75s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  79%|███████▉  | 141/178 [28:44<04:29,  7.29s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  85%|████████▌ | 152/178 [29:05<01:42,  3.92s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  88%|████████▊ | 157/178 [29:26<01:23,  4.00s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  89%|████████▉ | 158/178 [29:46<01:44,  5.25s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  89%|████████▉ | 159/178 [30:07<02:08,  6.77s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  90%|████████▉ | 160/178 [30:28<02:32,  8.47s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  90%|█████████ | 161/178 [30:48<02:54, 10.24s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  91%|█████████ | 162/178 [31:09<03:13, 12.09s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  97%|█████████▋| 172/178 [31:29<00:29,  4.89s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  97%|█████████▋| 173/178 [31:50<00:31,  6.38s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
#  98%|█████████▊| 174/178 [32:11<00:32,  8.07s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:36: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(temperature_raster_within_mountain_range[0] <= float(mountain_range_temperature), temperature_raster_within_mountain_range[0] != -999),
# 100%|██████████| 178/178 [32:32<00:00, 10.97s/it]
# Calculating the elevation for the treeline
#   0%|          | 0/178 [00:00<?, ?it/s]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#   1%|          | 1/178 [00:24<1:13:36, 24.95s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#   1%|          | 2/178 [00:48<1:11:36, 24.41s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#   2%|▏         | 3/178 [01:13<1:10:51, 24.29s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#   2%|▏         | 4/178 [01:37<1:10:12, 24.21s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#   3%|▎         | 5/178 [02:01<1:09:45, 24.19s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#   3%|▎         | 6/178 [02:26<1:10:12, 24.49s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#   4%|▍         | 7/178 [02:50<1:09:18, 24.32s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
# ...
#  54%|█████▍    | 97/178 [25:13<13:11,  9.78s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  57%|█████▋    | 101/178 [25:37<10:23,  8.10s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  57%|█████▋    | 102/178 [26:00<12:44, 10.06s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  58%|█████▊    | 103/178 [26:23<15:07, 12.10s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  58%|█████▊    | 104/178 [26:46<17:31, 14.21s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  59%|█████▉    | 105/178 [27:10<19:33, 16.08s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  62%|██████▏   | 110/178 [27:33<10:33,  9.31s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  62%|██████▏   | 111/178 [27:57<12:43, 11.39s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  63%|██████▎   | 112/178 [28:20<14:49, 13.48s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  64%|██████▍   | 114/178 [28:44<13:42, 12.86s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  65%|██████▍   | 115/178 [29:07<15:31, 14.79s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  69%|██████▊   | 122/178 [29:31<06:50,  7.33s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  72%|███████▏  | 128/178 [29:54<04:49,  5.80s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  72%|███████▏  | 129/178 [30:17<06:05,  7.47s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  74%|███████▎  | 131/178 [30:40<06:31,  8.33s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  75%|███████▍  | 133/178 [31:03<06:48,  9.09s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  75%|███████▌  | 134/178 [31:26<08:08, 11.10s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  77%|███████▋  | 137/178 [31:49<06:42,  9.81s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  79%|███████▉  | 141/178 [32:13<05:01,  8.15s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  85%|████████▌ | 152/178 [32:36<01:53,  4.38s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  88%|████████▊ | 157/178 [32:59<01:33,  4.46s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  89%|████████▉ | 158/178 [33:22<01:57,  5.86s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  89%|████████▉ | 159/178 [33:46<02:23,  7.57s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  90%|████████▉ | 160/178 [34:09<02:50,  9.48s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  90%|█████████ | 161/178 [34:32<03:15, 11.50s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  91%|█████████ | 162/178 [34:55<03:37, 13.57s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  97%|█████████▋| 172/178 [35:18<00:33,  5.52s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  97%|█████████▋| 173/178 [35:41<00:35,  7.18s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
#  98%|█████████▊| 174/178 [36:05<00:36,  9.07s/it]C:\Users\elren9761\AppData\Local\Temp\ipykernel_15464\3533603069.py:66: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   global_dem_mask = np.logical_or(global_dem_mask, np.where(np.logical_and(masked_temperature_raster <= float(mountain_range_temperature) + MARGIN, masked_temperature_raster >= float(mountain_range_temperature) - MARGIN),
# 100%|██████████| 178/178 [36:28<00:00, 12.30s/it]
# NO TEMPERATURES FOUND FOR FOLLOWING MOUNTAIN RANGE NAMES: Plateau of Mozambique
# Coro Region
# Venezuelan Coastal Range
# Guiana Highlands
# Tumucumaque Uplands
# Atlantic Plateau (Brazil)
# Eastern Arc Mountains
# Great Dividing Range
# Guinea Highlands
# Blue Ridge Mountains
# Central America Volcanic Arc
# Sahara Ranges
# Indian Subcontinent Ranges
# Korean Peninsula
# Arabian Peninsula
# Levant Ranges
# Great Plains
# U.S. Interior Highlands
# Fiji
# Marquesas Islands
# New Caledonia
# Vanuatu Islands
# Solomon Islands
# Society Islands
# Lesser Antilles
# Khentei-Daur Highlands
# Yankan - Tukuringra - Soktakhan - Dzhagdy group of mountain ranges
# Central Highland
# Maranhão-Piauí Highlands
# Southern Highland
# Northeastern Highland
# Horn of Africa Highlands
# Macaronesian Islands
# Saint Helena
# Ascension Island
# Tristan da Cunha
# Amsterdam Island
# Comoro Islands
# Seychelles
# Andaman and Nicobar Islands
# Flinders Lofty Block
# Central Ranges
# West Coast Ranges
# Northern Ranges
# Western Lowlands
# Eastern Escarpment (Madagascar)
# Central Plateau
# Appalachian Plateaus
# Appalachian Ridges
# Canadian Appalachians
# Northern U.S. Appalachians
# Piedmont-Southeast Coast
# Darien Isthmus Highlands*
# Chortís Highlands
# Volta Highlands
# Highlands North of the Amazon
# Nigerian Highlands
# Yablonov Mountain System*
# Southern Rift Mountains
# Northeast China Mountains
# Coastal Belt
# Greater Antilles
# Galapagos Islands
# Easter Island
# Samoan Islands
# Caroline Islands
# Mariana Islands
# Bismarck Archipelago
# Socotra Archipelago
# Ogasawara Islands
# Hoorn Islands
# Maghreb Mountains
# Central Range
# Cordones Serranos Bonaerenses
# Sudanese Highlands
# Lower Guinea Swell
# Kazakh Uplands
# Junggar Basin
# Asande Highland
# Juan Fernández Islands
# Desventuradas Islands
# Sri Lanka
# Central Tanzania
# Patom Highlands
# Tarim Basin

# %%
# Plot the treeline_extraction #>>> CHANGE FILE NAME <<< 
with rasterio.open("./data/elevation_treeline_biome/elevation_biome_chelsa_present.tif") as src: 
    plt.imshow(src.read(1)[::-1], cmap="terrain")
    # plot the mountain ranges
    plt.colorbar()
    plt.show()

# %%
# Plot the treeline_extraction upside down #>>> CHANGE FILE NAME <<< 
with rasterio.open("./data/elevation_treeline_biome/elevation_biome_chelsa_present.tif") as src: 
    plt.imshow(src.read(1)[::-1], cmap="terrain")
    # plot the mountain ranges
    plt.colorbar()
    plt.show()

# %%
#list the mountain ranges that have temperature
for temp in treeline_temp.iterrows():
    print(temp[1]["MapName"], temp[1]["MEAN_Avg_c"])
